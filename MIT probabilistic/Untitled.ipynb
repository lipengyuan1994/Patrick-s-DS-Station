# %%
from sympy import *

# %%
x = symbols('-(x^2)+b^2')
print (integrate (x,(x,-b,b)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-926000d8cbd5> in <module>
#       1 x = symbols('-(x^2)+b^2')
# ----> 2 print (integrate (x,(x,-b,b)))
#
# NameError: name 'b' is not defined
